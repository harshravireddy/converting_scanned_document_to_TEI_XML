# %%
from bs4 import BeautifulSoup
import re

# Read the HOCR file
with open("/content/combined_hocr_142539.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()

# Parse the HOCR content
soup = BeautifulSoup(hocr_content, "html.parser")

# Define a list of target IDs
target_ids = ["bbox 391 552 1289 659", "bbox 639 706 1047 763","bbox 499 813 1191 916"]

# Initialize a variable to store the extracted text
title_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        title_text += div.get_text(strip=True) + "\n"

# Find the div with class "ocr_carea" and title attribute containing "bbox 625 1995 1063 2041"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 625 1995 1063 2041" in value)

# Extract text from the second div with the specified format (\d+,\s\w+\s\d+)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)
    match = re.search(r"(\d{1,2}\.\s\w+\s\d{4})", text)
    if match:
        date_text = match.group(1)
else:
    date_text = ""

# Find the div with class "ocr_carea" and title attribute containing "bbox 251 2195 1439 2247"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 251 2195 1439 2247" in value)

place_text = ""

# Extract text from the found div
if div_place_tag:
    text = div_place_tag.get_text(strip=True)
    # Match both "Leipzig" and "Berlin" using regular expression
    matches = re.findall(r'\b(?:Leipzig|Berlin)\b', text)
    if matches:
        place_text = " und ".join(matches)  # Join the matches with " und " in between

# Find the div with class "ocr_carea" and title attribute containing "bbox 251 2195 1439 2247"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 251 2195 1439 2247" in value)

# Extract text from the third div with the specified format for orgName
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)
    match = re.search(r"[A-Z]{2},\s\w+", text)
    if match:
        org_name_text = match.group(0)
else:
    org_name_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 194 207 1484 354"
div_h1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 194 207 1484 354" in value)

# Extract text from the first div
if div_h1_tag:
    h1_text = div_h1_tag.get_text(strip=True)
else:
    h1_text = ""
# Define a list of target IDs
target_ids = ["bbox 391 552 1289 659", "bbox 639 706 1047 763","bbox 499 813 1191 916"]

# Initialize a variable to store the extracted text
h2_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        h2_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p1 attribute containing "bbox 712 1056 971 1105"
div_p1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 712 1056 971 1105" in value)

# Extract text from the first div
if div_p1_tag:
    p1_text = div_p1_tag.get_text(strip=True)
else:
    p1_text = ""
# Find the div with class "ocr_carea" and p1 attribute containing "bbox 297 1126 1381 1265"
div_p2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 297 1126 1381 1265" in value)

# Extract text from the first div
if div_p2_tag:
    p2_text = div_p2_tag.get_text(strip=True)
else:
    p2_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 685 1287 998 1391"
div_p3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 685 1287 998 1391" in value)

# Extract text from the first div
if div_p3_tag:
    p3_text = div_p3_tag.get_text(strip=True)
else:
    p3_text = ""
# Find the div with class "ocr_carea" and p2 attribute containing "bbox 639 1413 1052 1468"
div_p4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 639 1413 1052 1468" in value)

# Extract text from the first div
if div_p4_tag:
    p4_text = div_p4_tag.get_text(strip=True)
else:
    p4_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 357 1566 1332 1885"
div_p5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 357 1566 1332 1885" in value)

# Extract text from the first div
if div_p5_tag:
    p5_text = div_p5_tag.get_text(strip=True)
else:
    p5_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 625 1995 1063 2041"
div_p6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 625 1995 1063 2041" in value)

# Extract text from the first div
if div_p6_tag:
    p6_text = div_p6_tag.get_text(strip=True)
else:
    p6_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 251 2195 1439 2247"
div_p7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 251 2195 1439 2247" in value)

# Extract text from the first div
if div_p7_tag:
    p7_text = div_p7_tag.get_text(strip=True)
else:
    p7_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 193 165 1485 413"
div_h3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 193 165 1485 413" in value)

# Extract text from the first div
if div_h3_tag:
    h3_text = div_h3_tag.get_text(strip=True)
else:
    h3_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 194 550 984 617"
div_h4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 194 550 984 617" in value)

# Extract text from the first div
if div_h4_tag:
    h4_text = div_h4_tag.get_text(strip=True)
else:
    h4_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 430 634 1489 892"
div_p8_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 430 634 1489 892" in value)

# Extract text from the first div
if div_p8_tag:
    p8_text = div_p8_tag.get_text(strip=True)
else:
    p8_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 197 974 1484 1037"
div_h5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 197 974 1484 1037" in value)

# Extract text from the first div
if div_h5_tag:
    h5_text = div_h5_tag.get_text(strip=True)
else:
    h5_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 197 1055 1492 2132"
div_l1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 197 1055 1492 2132" in value)

# Extract text from the first div
if div_l1_tag:
    l1_text = div_l1_tag.get_text(strip=True)
else:
    l1_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 214 2152 1034 2205"
div_l2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 214 2152 1034 2205" in value)

# Extract text from the first div
if div_l2_tag:
    l2_text = div_l2_tag.get_text(strip=True)
else:
    l2_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 993 179 2237 875"
div_p9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 993 179 2237 875" in value)

# Extract text from the first div
if div_p9_tag:
    p9_text = div_p9_tag.get_text(strip=True)
else:
    p9_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 938 930 1517 986"
div_h6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 938 930 1517 986" in value)

# Extract text from the first div
if div_h6_tag:
    h6_text = div_h6_tag.get_text(strip=True)
else:
    h6_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 989 996 2235 1501"
div_p10_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 989 996 2235 1501" in value)

# Extract text from the first div
if div_p10_tag:
    p10_text = div_p10_tag.get_text(strip=True)
else:
    p10_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1292 1520 2234 1573"
div_p11_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1292 1520 2234 1573" in value)

# Extract text from the first div
if div_p11_tag:
    p11_text = div_p11_tag.get_text(strip=True)
else:
    p11_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 997 1914 2231 2009"
div_p12_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 997 1914 2231 2009" in value)

# Extract text from the first div
if div_p12_tag:
    p12_text = div_p12_tag.get_text(strip=True)
else:
    p12_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1268 2020 2232 2215"
div_p13_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1268 2020 2232 2215" in value)

# Extract text from the first div
if div_p13_tag:
    p13_text = div_p13_tag.get_text(strip=True)
else:
    p13_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 981 197 2228 1204"
div_p14_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 981 197 2228 1204" in value)

# Extract text from the first div
if div_p14_tag:
    p14_text = div_p14_tag.get_text(strip=True)
else:
    p14_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 982 1268 1611 1323"
div_h7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 982 1268 1611 1323" in value)

# Extract text from the first div
if div_h7_tag:
    h7_text = div_h7_tag.get_text(strip=True)
else:
    h7_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 978 1339 2225 1971"
div_p15_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 978 1339 2225 1971" in value)

# Extract text from the first div
if div_p15_tag:
    p15_text = div_p15_tag.get_text(strip=True)
else:
    p15_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 987 2027 1149 2083"
div_h8_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 987 2027 1149 2083" in value)

# Extract text from the first div
if div_h8_tag:
    h8_text = div_h8_tag.get_text(strip=True)
else:
    h8_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 981 2096 2223 2240"
div_p16_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 981 2096 2223 2240" in value)

# Extract text from the first div
if div_p16_tag:
    p16_text = div_p16_tag.get_text(strip=True)
else:
    p16_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 311 200 1567 922"
div_p17_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 311 200 1567 922" in value)

# Extract text from the first div
if div_p17_tag:
    p17_text = div_p17_tag.get_text(strip=True)
else:
    p17_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 313 998 698 1052"
div_h9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 313 998 698 1052" in value)

# Extract text from the first div
if div_h9_tag:
    h9_text = div_h9_tag.get_text(strip=True)
else:
    h9_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 315 1067 1559 1252"
div_p18_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 315 1067 1559 1252" in value)

# Extract text from the first div
if div_p18_tag:
    p18_text = div_p18_tag.get_text(strip=True)
else:
    p18_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 313 1327 628 1383"
div_h10_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 313 1327 628 1383" in value)

# Extract text from the first div
if div_h10_tag:
    h10_text = div_h10_tag.get_text(strip=True)
else:
    h10_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 311 1397 1555 1539"
div_p19_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 311 1397 1555 1539" in value)

# Extract text from the first div
if div_p19_tag:
    p19_text = div_p19_tag.get_text(strip=True)
else:
    p19_text = ""

# Create TEI XML document
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <persName></persName>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
    <head>{h1_text}</head>
    <div type="heading">
        <head>{h2_text}</head>
        <p>{p1_text}</p>
        <p>{p2_text}</p>
        <p>{p3_text}</p>
        <p>{p4_text}</p>
        <p>{p5_text}</p>
        <p>{p6_text}</p>
        <p>{p7_text}</p>
        </div>
        <div type="heading">
        <head>{h3_text}</head>
        </div>
        <div type="subheading">
        <head>{h4_text}</head>
        <p>{p8_text}</p>
        <head>{h5_text}</head>
        <list type="number">
        <item n='1'>{l1_text}</item>
        <item n='2'>{l2_text}</item>
        </list>
        </div>
        <div>
        <p>{p9_text}</p>
        <head>{h6_text}</head>
        <p>{p10_text}</p>
        <p>{p11_text}</p>
        <p>{p12_text}</p>
        <p>{p13_text}</p>
        </div>
        <div>
        <p>{p14_text}</p>
        <head>{h7_text}</head>
        <p>{p15_text}</p>
        <head>{h8_text}</head>
        <p>{p16_text}</p>
        </div>
        <div>
        <p>{p17_text}</p>
        <head>{h9_text}</head>
        <p>{p18_text}</p>
        <head>{h10_text}</head>
        <p>{p19_text}</p>
        </div>
    </body>
  </text>
</TEI>
"""

# Write TEI XML document to file
with open("output_142539.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)
