# %%
from bs4 import BeautifulSoup
import re

# Read the HOCR file
with open("/content/combined_hocr_werkgehilfin.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()

# Parse the HOCR content
soup = BeautifulSoup(hocr_content, "html.parser")

target_ids = ["bbox 364 564 1326 779", "bbox 589 837 1107 944"]

# Initialize a variable to store the extracted text
title_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        title_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and title attribute containing "bbox 624 1921 1110 1974"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 624 1921 1110 1974" in value)

# Extract text from the second div with the specified format (\d+,\s\w+\s\d+)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)
    match = re.search(r"(\d{1,2},\s\w+\s\d{4})", text)
    if match:
        date_text = match.group(1)
else:
    date_text = ""

# Find the div with class "ocr_carea" and title attribute containing "bbox 267 2161 1467 2229"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 267 2161 1467 2229" in value)

place_text = ""

# Extract text from the found div
if div_place_tag:
    text = div_place_tag.get_text(strip=True)
    # Match both "Leipzig" and "Berlin" using regular expression
    matches = re.findall(r'\b(?:Leipzig|Berlin)\b', text)
    if matches:
        place_text = " und ".join(matches)  # Join the matches with " und " in between


# Find the div with class "ocr_carea" and title attribute containing "bbox 267 2161 1467 2229"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 267 2161 1467 2229" in value)

# Extract text from the third div with the specified format for orgName
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)
    match = re.search(r"\b[A-Z]\.[A-Z]\. [A-Z][a-z]+\b", text)
    if match:
        org_name_text = match.group(0)
else:
    org_name_text = ""

# Find the div with class "ocr_carea" and head1 attribute containing "bbox 267 187 1488 341"
div_h1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 267 187 1488 341" in value)

# Extract text from the first div
if div_h1_tag:
    h1_text = div_h1_tag.get_text(strip=True)
else:
    h1_text = ""
# Find the div with class "ocr_carea" and p1 attribute containing "bbox 726 1067 975 1116"
div_p1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 726 1067 975 1116" in value)

# Extract text from the first div
if div_p1_tag:
    p1_text = div_p1_tag.get_text(strip=True)
else:
    p1_text = ""

# Find the div with class "ocr_carea" and p2 attribute containing "bbox 325 1147 1380 1303"
div_p2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 325 1147 1380 1303" in value)

# Extract text from the first div
if div_p2_tag:
    p2_text = div_p2_tag.get_text(strip=True)
else:
    p2_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 369 1444 1349 1785"
div_p3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 369 1444 1349 1785" in value)

# Extract text from the first div
if div_p3_tag:
    p3_text = div_p3_tag.get_text(strip=True)
else:
    p3_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 624 1921 1110 1974"
div_p4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 624 1921 1110 1974" in value)

# Extract text from the first div
if div_p4_tag:
    p4_text = div_p4_tag.get_text(strip=True)
else:
    p4_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 267 2161 1467 2229"
div_p5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 267 2161 1467 2229" in value)

# Extract text from the first div
if div_p5_tag:
    p5_text = div_p5_tag.get_text(strip=True)
else:
    p5_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1579 401 1869 451"
div_h2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1579 401 1869 451" in value)

# Extract text from the first div
if div_h2_tag:
    h2_text = div_h2_tag.get_text(strip=True)
else:
    h2_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1266 458 2176 686"
div_p6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1266 458 2176 686" in value)

# Extract text from the first div
if div_p6_tag:
    p6_text = div_p6_tag.get_text(strip=True)
else:
    p6_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1266 723 1861 819"
div_h3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1266 723 1861 819" in value)

# Extract text from the first div
if div_h3_tag:
    h3_text = div_h3_tag.get_text(strip=True)
else:
    h3_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1266 821 2176 961"
div_p7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1266 821 2176 961" in value)

# Extract text from the first div
if div_p7_tag:
    p7_text = div_p7_tag.get_text(strip=True)
else:
    p7_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1266 1004 1646 1052"
div_h4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1266 1004 1646 1052" in value)

# Extract text from the first div
if div_h4_tag:
    h4_text = div_h4_tag.get_text(strip=True)
else:
    h4_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1585 1069 1847 1114"
div_h5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1585 1069 1847 1114" in value)

# Extract text from the first div
if div_h5_tag:
    h5_text = div_h5_tag.get_text(strip=True)
else:
    h5_text = ""
# Define a list of target IDs
target_ids = ["bbox 1262 1118 2211 1478", "bbox 1263 1472 2110 1538"]

# Initialize a variable to store the extracted text
p8_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p8_text += div.get_text(strip=True) + "\n"

div_h6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1264 1557 2200 1803" in value)

# Extract text from the first div
if div_h6_tag:
    h6_text = div_h6_tag.get_text(strip=True)
else:
    h6_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1264 1795 2174 1886"
div_p9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1264 1795 2174 1886" in value)

# Extract text from the first div
if div_p9_tag:
    p9_text = div_p9_tag.get_text(strip=True)
else:
    p9_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1572 1896 1874 1945"
div_p10_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1572 1896 1874 1945" in value)

# Extract text from the first div
if div_p10_tag:
    p10_text = div_p10_tag.get_text(strip=True)
else:
    p10_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1597 2189 1834 2226"
div_p11_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1597 2189 1834 2226" in value)

# Extract text from the first div
if div_p11_tag:
    p11_text = div_p11_tag.get_text(strip=True)
else:
    p11_text = ""

# Define a list of target IDs
target_ids = ["bbox 231 162 1518 249", "bbox 601 265 1143 398"]

# Initialize a variable to store the extracted text
h7_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        h7_text += div.get_text(strip=True) + "\n"
div_h8_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 228 527 906 595" in value)

# Extract text from the first div
if div_h8_tag:
    h8_text = div_h8_tag.get_text(strip=True)
else:
    h8_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 220 615 1519 1110"
div_p12_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 220 615 1519 1110" in value)

# Extract text from the first div
if div_p12_tag:
    p12_text = div_p12_tag.get_text(strip=True)
else:
    p12_text = ""
div_h9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 228 1191 1519 1329" in value)

# Extract text from the first div
if div_h9_tag:
    h9_text = div_h9_tag.get_text(strip=True)
else:
    h9_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 220 1350 1521 1940"
div_l1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 220 1350 1521 1940" in value)

# Extract text from the first div
if div_l1_tag:
    l1_text = div_l1_tag.get_text(strip=True)
else:
    l1_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 227 1956 1520 2205"
div_l2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 227 1956 1520 2205" in value)

# Extract text from the first div
if div_l2_tag:
    l2_text = div_l2_tag.get_text(strip=True)
else:
    l2_text = ""

div_h10_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1021 160 1571 233" in value)

# Extract text from the first div
if div_h10_tag:
    h10_text = div_h10_tag.get_text(strip=True)
else:
    h10_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1015 252 2377 1098"
div_p13_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1015 252 2377 1098" in value)

# Extract text from the first div
if div_p13_tag:
    p13_text = div_p13_tag.get_text(strip=True)
else:
    p13_text = ""

div_h11_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1023 1201 1379 1261" in value)

# Extract text from the first div
if div_h11_tag:
    h11_text = div_h11_tag.get_text(strip=True)
else:
    h11_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1081 1289 2381 1699"
div_p14_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1081 1289 2381 1699" in value)

# Extract text from the first div
if div_p14_tag:
    p14_text = div_p14_tag.get_text(strip=True)
else:
    p14_text = ""
div_l3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1023 1770 2318 2199" in value)

# Extract text from the first div
if div_l3_tag:
    l3_text = div_l3_tag.get_text(strip=True)
else:
    l3_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 275 167 1523 1382"
div_p15_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 275 167 1523 1382" in value)

# Extract text from the first div
if div_p15_tag:
    p15_text = div_p15_tag.get_text(strip=True)
else:
    p15_text = ""
div_l4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 249 1464 1523 2281" in value)

# Extract text from the first div
if div_l4_tag:
    l4_text = div_l4_tag.get_text(strip=True)
else:
    l4_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1051 169 2292 1018"
div_p16_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 1051 169 2292 1018" in value)

# Extract text from the first div
if div_p16_tag:
    p16_text = div_p16_tag.get_text(strip=True)
else:
    p16_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 1051 169 2292 1018"
div_p17_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 313 309 1428 397" in value)

# Extract text from the first div
if div_p17_tag:
    p17_text = div_p17_tag.get_text(strip=True)
else:
    p17_text = ""
div_h12_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 604 436 1139 488" in value)

# Extract text from the first div
if div_h12_tag:
    h12_text = div_h12_tag.get_text(strip=True)
else:
    h12_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 309 493 1429 724"
div_p18_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 309 493 1429 724" in value)

# Extract text from the first div
if div_p18_tag:
    p18_text = div_p18_tag.get_text(strip=True)
else:
    p18_text = ""
div_h13_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 683 760 1057 812" in value)

# Extract text from the first div
if div_h13_tag:
    h13_text = div_h13_tag.get_text(strip=True)
else:
    h13_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 310 822 1430 1135"
div_p19_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 310 822 1430 1135" in value)

# Extract text from the first div
if div_p19_tag:
    p19_text = div_p19_tag.get_text(strip=True)
else:
    p19_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 304 1178 1430 1588"
div_p20_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 304 1178 1430 1588" in value)

# Extract text from the first div
if div_p20_tag:
    p20_text = div_p20_tag.get_text(strip=True)
else:
    p20_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 303 1630 1428 1920"
div_p21_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 303 1630 1428 1920" in value)

# Extract text from the first div
if div_p21_tag:
    p21_text = div_p21_tag.get_text(strip=True)
else:
    p21_text = ""
div_h14_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 619 1955 1117 2009" in value)

# Extract text from the first div
if div_h14_tag:
    h14_text = div_h14_tag.get_text(strip=True)
else:
    h14_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 303 1999 1429 2157"
div_p22_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 303 1999 1429 2157" in value)

# Extract text from the first div
if div_p22_tag:
    p22_text = div_p22_tag.get_text(strip=True)
else:
    p22_text = ""
# Create TEI XML document
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <persName></persName>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
    <div type="heading">
     <head>{h1_text}</head>
       <p>{p1_text} </p>
        <p>{p2_text}</p>
        <p>{p3_text}</p>
        <p>{p4_text}</p>
        <p>{p5_text}</p>
      </div>
      <div>
        <head>{h2_text}</head>
        <p>{p6_text}</p>
        <head>{h3_text}</head>
        <p>{p7_text}</p>
        <head>{h4_text}</head>
        <head>{h5_text}</head>
         <p>{p8_text}</p>
        <head>{h6_text}</head>
        <p>{p9_text}</p>
        <p>{p10_text}</p>
        <p>{p11_text}</p>
      </div>
       <div>
       <head>{h7_text}</head>
       <head>{h8_text}</head>
      <p>{p12_text}</p>
      <head>{h9_text}</head>
      <list type="number">
          <item n="1">{l1_text}</item>
          <item n="2">{l2_text}</item>
      </list>
     </div>
     <div>
       <head>{h10_text}</head>
       <p>{p13_text}</p>
       <head>{h11_text}</head>
      <p>{p14_text}</p>
      <list type="number">
          <item n="3">{l3_text}</item>
      </list>
      </div>
      <div>
          <p>{p15_text}</p>
      <list type="number">
          <item n="4">{l4_text}</item>
      </list>
      </div>
      <div>
       <p>{p16_text}</p>
      </div>
      <div>
      <p>{p17_text}</p>
        <head>{h12_text}</head>
        <p>{p18_text}</p>
        <head>{h13_text}</head>
        <p>{p19_text}</p>
        <p>{p20_text}</p>
        <p>{p22_text}</p>
        <head>{h14_text}</head>
        <p>{p22_text}</p>
      </div>
    </body>
  </text>
</TEI>
"""

# Write TEI XML document to file
with open("output_werkgehilfin_tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)
