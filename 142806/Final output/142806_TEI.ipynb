# %%
from bs4 import BeautifulSoup
import re

# Read the HOCR file
with open("/content/combined_hocr_142806.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()

# Parse the HOCR content
soup = BeautifulSoup(hocr_content, "html.parser")

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 108 343 684 483"
div_title_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 108 343 684 483" in value)

# Extract text from the first div
if div_title_tag:
    title_text = div_title_tag.get_text(strip=True)
else:
    title_text = ""
# Find the div with class "ocr_carea" and title attribute containing "bbox 253 1082 543 1116"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 253 1082 543 1116" in value)

# Extract text from the second div with the specified format (\d+,\s\w+\s\d+)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)
    match = re.search(r'\d{1,2}\.\s\w+\s\d{4}', text)
    if match:
        date_text = match.group(0)
else:
    date_text = ""

# Find the div with class "ocr_carea" and title attribute containing "bbox 0 1272 794 1309"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 0 1272 794 1309" in value)

place_text = ""

# Extract text from the found div
if div_place_tag:
    text = div_place_tag.get_text(strip=True)
    # Match both "Leipzig" and "Berlin" using regular expression
    matches = re.findall(r'in\s(Leipzig\sund\sBerlin)', text)
    if matches:
        place_text = " und ".join(matches)  # Join the matches with " und " in between

# Find the div with class "ocr_carea" and title attribute containing "bbox 0 1272 794 1309"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 0 1272 794 1309" in value)

# Extract text from the third div with the specified format for orgName
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)
    match = re.search(r"BG, Teubner", text)
    if match:
        org_name_text = match.group(0)
else:
    org_name_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 0 8 792 217"
div_h1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 0 8 792 217" in value)

# Extract text from the first div
if div_h1_tag:
    h1_text = div_h1_tag.get_text(strip=True)
else:
    h1_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 108 343 684 483"
div_h2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 108 343 684 483" in value)

# Extract text from the first div
if div_h2_tag:
    h2_text = div_h2_tag.get_text(strip=True)
else:
    h2_text = ""

# Find the div with class "ocr_carea" and p1 attribute containing "bbox 21 566 773 944"
div_p1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 21 566 773 944" in value)

# Extract text from the first div
if div_p1_tag:
    p1_text = div_p1_tag.get_text(strip=True)
else:
    p1_text = ""
# Find the div with class "ocr_carea" and p1 attribute containing "bbox 253 1082 543 1116"
div_p2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 253 1082 543 1116" in value)

# Extract text from the first div
if div_p2_tag:
    p2_text = div_p2_tag.get_text(strip=True)
else:
    p2_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 0 1272 794 1309"
div_p3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 0 1272 794 1309" in value)

# Extract text from the first div
if div_p3_tag:
    p3_text = div_p3_tag.get_text(strip=True)
else:
    p3_text = ""
# Find the div with class "ocr_carea" and p2 attribute containing "bbox 694 1340 847 1369"
div_p4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 694 1340 847 1369" in value)

# Extract text from the first div
if div_p4_tag:
    p4_text = div_p4_tag.get_text(strip=True)
else:
    p4_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 44 5 1259 159"
div_h3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 44 5 1259 159" in value)

# Extract text from the first div
if div_h3_tag:
    h3_text = div_h3_tag.get_text(strip=True)
else:
    h3_text = ""
# Define a list of target IDs
target_ids = ["bbox 462 169 939 264", "bbox 466 261 903 311"]

# Initialize a variable to store the extracted text
p5_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p5_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 42 356 840 419"
div_h4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 42 356 840 419" in value)

# Extract text from the first div
if div_h4_tag:
    h4_text = div_h4_tag.get_text(strip=True)
else:
    h4_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 273 441 1263 601"
div_p6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 273 441 1263 601" in value)

# Extract text from the first div
if div_p6_tag:
    p6_text = div_p6_tag.get_text(strip=True)
else:
    p6_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 46 685 1201 745"
div_h5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 46 685 1201 745" in value)

# Extract text from the first div
if div_h5_tag:
    h5_text = div_h5_tag.get_text(strip=True)
else:
    h5_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 43 766 1267 1857"
div_p7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 43 766 1267 1857" in value)

# Extract text from the first div
if div_p7_tag:
    p7_text = div_p7_tag.get_text(strip=True)
else:
    p7_text = ""


# Find the div with class "ocr_carea" and p3 attribute containing "bbox 61 1884 1069 1935"
div_p8_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 61 1884 1069 1935" in value)

# Extract text from the first div
if div_p8_tag:
    p8_text = div_p8_tag.get_text(strip=True)
else:
    p8_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 11 26 504 96"
div_h6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 11 26 504 96" in value)

# Extract text from the first div
if div_h6_tag:
    h6_text = div_h6_tag.get_text(strip=True)
else:
    h6_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 11 125 1256 1121"
div_p9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 11 125 1256 1121" in value)

# Extract text from the first div
if div_p9_tag:
    p9_text = div_p9_tag.get_text(strip=True)
else:
    p9_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 16 1244 583 1314"
div_h7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 16 1244 583 1314" in value)

# Extract text from the first div
if div_h7_tag:
    h7_text = div_h7_tag.get_text(strip=True)
else:
    h7_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 20 1328 1256 1949"
div_p10_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 20 1328 1256 1949" in value)

# Extract text from the first div
if div_p10_tag:
    p10_text = div_p10_tag.get_text(strip=True)
else:
    p10_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 85 12 1248 196"
div_p11_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 85 12 1248 196" in value)

# Extract text from the first div
if div_p11_tag:
    p11_text = div_p11_tag.get_text(strip=True)
else:
    p11_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 87 251 1249 911"
div_p12_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 87 251 1249 911" in value)

# Extract text from the first div
if div_p12_tag:
    p12_text = div_p12_tag.get_text(strip=True)
else:
    p12_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 91 969 1252 1290"
div_p13_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 91 969 1252 1290" in value)

# Extract text from the first div
if div_p13_tag:
    p13_text = div_p13_tag.get_text(strip=True)
else:
    p13_text = ""

# Define a list of target IDs
target_ids = ["bbox 91 1345 1250 1872","bbox 87 1896 225 1940"]

# Initialize a variable to store the extracted text
p14_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p14_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 28 15 990 86""
div_h8_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 28 15 990 86" in value)

# Extract text from the first div
if div_h8_tag:
    h8_text = div_h8_tag.get_text(strip=True)
else:
    h8_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 85 114 1245 528"
div_p15_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 85 114 1245 528" in value)

# Extract text from the first div
if div_p15_tag:
    p15_text = div_p15_tag.get_text(strip=True)
else:
    p15_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 59 577 319 634"
div_h9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 59 577 319 634" in value)

# Extract text from the first div
if div_h9_tag:
    h9_text = div_h9_tag.get_text(strip=True)
else:
    h9_text = ""
# Define a list of target IDs
target_ids = ["bbox 84 659 1243 843","bbox 85 859 391 907"]

# Initialize a variable to store the extracted text
p16_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p16_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 84 975 1243 1233"
div_p17_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 84 975 1243 1233" in value)

# Extract text from the first div
if div_p17_tag:
    p17_text = div_p17_tag.get_text(strip=True)
else:
    p17_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 84 1296 975 1894"
div_p18_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 84 1296 975 1894" in value)

# Extract text from the first div
if div_p18_tag:
    p18_text = div_p18_tag.get_text(strip=True)
else:
    p18_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 38 32 1261 638"
div_p19_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 38 32 1261 638" in value)

# Extract text from the first div
if div_p19_tag:
    p19_text = div_p19_tag.get_text(strip=True)
else:
    p19_text = ""



# Create TEI XML document
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <persName></persName>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
    <div type="heading">
     <head>{h1_text}</head>
     </div>
    <div type="subheading">
        <head>{h2_text}</head>
        <p>{p1_text}</p>
        <p>{p2_text}</p>
        <p>{p3_text}</p>
        <p>{p4_text}</p>
        </div>
        <div>
        <head>{h3_text}</head>
        <p>{p5_text}</p>
        <head>{h4_text}</head>
        <p>{p6_text}</p>
        <head>{h5_text}</head>
        <p>{p7_text}</p>
        <p>{p8_text}</p>
        </div>
        <div>
        <head>{h6_text}</head>
        <p>{p9_text}</p>
        <head>{h7_text}</head>
        <p>{p10_text}</p>
        </div>
        <div>
        <p>{p11_text}</p>
        <p>{p12_text}</p>
        <p>{p13_text}</p>
        <p>{p14_text}</p>
        </div>
        <div>
        <head>{h8_text}</head>
        <p>{p15_text}</p>
        <head>{h9_text}</head>
        <p>{p16_text}</p>
        <p>{p17_text}</p>
        <p>{p18_text}</p>
        </div>
        <div>
        <p>{p19_text}</p>
        </div>
    </body>
  </text>
</TEI>
"""

# Write TEI XML document to file
with open("output_142806.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)
