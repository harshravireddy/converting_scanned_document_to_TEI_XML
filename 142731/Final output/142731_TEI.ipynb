# %%
from bs4 import BeautifulSoup
import re

# Read the HOCR file
with open("/content/combined_hocr_142731.hocr", "r", encoding="utf-8") as file:
    hocr_content = file.read()

# Parse the HOCR content
soup = BeautifulSoup(hocr_content, "html.parser")

# Define a list of target IDs
target_ids = ["bbox 169 380 977 459", "bbox 346 486 794 531","bbox 300 561 838 636"]

# Initialize a variable to store the extracted text
title_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        title_text += div.get_text(strip=True) + "\n"

# Find the div with class "ocr_carea" and title attribute containing "bbox 421 1345 706 1382"
div_date_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 421 1345 706 1382" in value)

# Extract text from the second div with the specified format (\d+,\s\w+\s\d+)
if div_date_tag:
    date_text = ""
    text = div_date_tag.get_text(strip=True)
    match = re.search(r"(\d{1,2},\s\w+\s\d{4})", text)
    if match:
        date_text = match.group(1)
else:
    date_text = ""

# Find the div with class "ocr_carea" and title attribute containing "bbox 132 1441 993 1506"
div_place_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 132 1441 993 1506" in value)

place_text = ""

# Extract text from the found div
if div_place_tag:
    text = div_place_tag.get_text(strip=True)
    # Match both "Leipzig" and "Berlin" using regular expression
    matches = re.findall(r'in\s(Leipzig\sund\sBerlin)\b', text)
    if matches:
        place_text = " und ".join(matches)  # Join the matches with " und " in between

# Find the div with class "ocr_carea" and title attribute containing "bbox 132 1441 993 1506"
div_org_name_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 132 1441 993 1506" in value)

# Extract text from the third div with the specified format for orgName
if div_org_name_tag:
    org_name_text = ""
    text = div_org_name_tag.get_text(strip=True)
    match = re.search(r'\b[A-Z]\.\s[A-Z]\.\s\w+', text)
    if match:
        org_name_text = match.group(0)
else:
    org_name_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 143 137 1002 240"
div_h1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 143 137 1002 240" in value)

# Extract text from the first div
if div_h1_tag:
    h1_text = div_h1_tag.get_text(strip=True)
else:
    h1_text = ""
# Define a list of target IDs
target_ids = ["bbox 169 380 977 459", "bbox 346 486 794 531","bbox 300 561 838 636"]

# Initialize a variable to store the extracted text
h2_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        h2_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p1 attribute containing "bbox 214 699 923 796"
div_p1_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 214 699 923 796" in value)

# Extract text from the first div
if div_p1_tag:
    p1_text = div_p1_tag.get_text(strip=True)
else:
    p1_text = ""
# Find the div with class "ocr_carea" and p1 attribute containing "bbox 429 818 701 936"
div_p2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 429 818 701 936" in value)

# Extract text from the first div
if div_p2_tag:
    p2_text = div_p2_tag.get_text(strip=True)
else:
    p2_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 129 1010 891 1278"
div_p3_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 129 1010 891 1278" in value)

# Extract text from the first div
if div_p3_tag:
    p3_text = div_p3_tag.get_text(strip=True)
else:
    p3_text = ""
# Find the div with class "ocr_carea" and p2 attribute containing "bbox 421 1345 706 1382"
div_p4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 421 1345 706 1382" in value)

# Extract text from the first div
if div_p4_tag:
    p4_text = div_p4_tag.get_text(strip=True)
else:
    p4_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 132 1441 993 1506"
div_p5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 132 1441 993 1506" in value)

# Extract text from the first div
if div_p5_tag:
    p5_text = div_p5_tag.get_text(strip=True)
else:
    p5_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 625 1995 1063 2041"
div_p6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 625 1995 1063 2041" in value)

# Extract text from the first div
if div_p6_tag:
    p6_text = div_p6_tag.get_text(strip=True)
else:
    p6_text = ""
# Define a list of target IDs
target_ids = ["bbox 511 189 1243 339", "bbox 628 367 1120 435"]

# Initialize a variable to store the extracted text
h3_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        h3_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 266 465 1482 611"
div_h4_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 266 465 1482 611" in value)

# Extract text from the first div
if div_h4_tag:
    h4_text = div_h4_tag.get_text(strip=True)
else:
    h4_text = ""
# Define a list of target IDs
target_ids = ["bbox 538 690 1208 748", "bbox 265 766 1481 941"]

# Initialize a variable to store the extracted text
l1_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        l1_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 574 949 1481 1033"
div_l2_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 574 949 1481 1033" in value)

# Extract text from the first div
if div_l2_tag:
    l2_text = div_l2_tag.get_text(strip=True)
else:
    l2_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 264 1060 1480 1153"
div_h5_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 264 1060 1480 1153" in value)

# Extract text from the first div
if div_h5_tag:
    h5_text = div_h5_tag.get_text(strip=True)
else:
    h5_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 616 1232 1131 1289"
div_h6_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 616 1232 1131 1289" in value)

# Extract text from the first div
if div_h6_tag:
    h6_text = div_h6_tag.get_text(strip=True)
else:
    h6_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 265 1309 1479 1569"
div_p7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 265 1309 1479 1569" in value)

# Extract text from the first div
if div_p7_tag:
    p7_text = div_p7_tag.get_text(strip=True)
else:
    p7_text = ""


# Find the div with class "ocr_carea" and p3 attribute containing "bbox 516 1589 1121 1635"
div_p8_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 516 1589 1121 1635" in value)

# Extract text from the first div
if div_p8_tag:
    p8_text = div_p8_tag.get_text(strip=True)
else:
    p8_text = ""


# Find the div with class "ocr_carea" and p3 attribute containing "bbox 518 1657 1280 1765"
div_p9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 518 1657 1280 1765" in value)

# Extract text from the first div
if div_p9_tag:
    p9_text = div_p9_tag.get_text(strip=True)
else:
    p9_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 517 1770 1387 1822"
div_p10_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 517 1770 1387 1822" in value)

# Extract text from the first div
if div_p10_tag:
    p10_text = div_p10_tag.get_text(strip=True)
else:
    p10_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 569 1820 1478 1953"
div_p11_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 569 1820 1478 1953" in value)

# Extract text from the first div
if div_p11_tag:
    p11_text = div_p11_tag.get_text(strip=True)
else:
    p11_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 516 1971 1478 2107"
div_p12_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 516 1971 1478 2107" in value)

# Extract text from the first div
if div_p12_tag:
    p12_text = div_p12_tag.get_text(strip=True)
else:
    p12_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 193 189 382 245"
div_h7_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 193 189 382 245" in value)

# Extract text from the first div
if div_h7_tag:
    h7_text = div_h7_tag.get_text(strip=True)
else:
    h7_text = ""
# Define a list of target IDs
target_ids = ["bbox 447 191 1330 341", "bbox 501 342 1411 430"]

# Initialize a variable to store the extracted text
p13_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p13_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 195 447 957 497""
div_h8_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 195 447 957 497" in value)

# Extract text from the first div
if div_h8_tag:
    h8_text = div_h8_tag.get_text(strip=True)
else:
    h8_text = ""
# Define a list of target IDs
target_ids = ["bbox 446 510 1411 643","bbox 445 646 1410 742", "bbox 446 752 1411 842",]

# Initialize a variable to store the extracted text
p14_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p14_text += div.get_text(strip=True) + "\n"
# Define a list of target IDs
target_ids = ["bbox 447 852 1411 945","bbox 447 941 1277 1049", "bbox 447 1058 1410 1194",]

# Initialize a variable to store the extracted text
p15_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p15_text += div.get_text(strip=True) + "\n"
# Define a list of target IDs
target_ids = ["bbox 445 1202 1325 1258","bbox 446 1260 1409 1352", "bbox 445 1361 1410 2019","bbox 445 2025 1408 2117"]

# Initialize a variable to store the extracted text
p16_text = ""

# Loop over each target ID
for target_id in target_ids:
    # Find the div element with the specified class and title
    div = soup.find("div", class_="ocr_carea", title=lambda value: value and target_id in value)

    # Extract text from the div if found
    if div:
        p16_text += div.get_text(strip=True) + "\n"
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 440 135 780 181"
div_h9_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 440 135 780 181" in value)

# Extract text from the first div
if div_h9_tag:
    h9_text = div_h9_tag.get_text(strip=True)
else:
    h9_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 182 195 1041 420"
div_p17_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 182 195 1041 420" in value)

# Extract text from the first div
if div_p17_tag:
    p17_text = div_p17_tag.get_text(strip=True)
else:
    p17_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 358 427 763 466"
div_h10_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 358 427 763 466" in value)

# Extract text from the first div
if div_h10_tag:
    h10_text = div_h10_tag.get_text(strip=True)
else:
    h10_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 395 464 1047 553"
div_p18_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 395 464 1047 553" in value)

# Extract text from the first div
if div_p18_tag:
    p18_text = div_p18_tag.get_text(strip=True)
else:
    p18_text = ""

# Find the div with class "ocr_carea" and p3 attribute containing "bbox 356 541 1041 734"
div_p19_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 356 541 1041 734" in value)

# Extract text from the first div
if div_p19_tag:
    p19_text = div_p19_tag.get_text(strip=True)
else:
    p19_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 356 743 1040 965"
div_p20_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 356 743 1040 965" in value)

# Extract text from the first div
if div_p20_tag:
    p20_text = div_p20_tag.get_text(strip=True)
else:
    p20_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 354 975 1039 1196"
div_p21_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 354 975 1039 1196" in value)

# Extract text from the first div
if div_p21_tag:
    p21_text = div_p21_tag.get_text(strip=True)
else:
    p21_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 175 1210 940 1249"
div_p22_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 175 1210 940 1249" in value)

# Extract text from the first div
if div_p22_tag:
    p22_text = div_p22_tag.get_text(strip=True)
else:
    p22_text = ""
# Find the div with class "ocr_carea" and p3 attribute containing "bbox 353 1258 1036 1330"
div_p23_tag = soup.find("div", class_="ocr_carea", title=lambda value: value and "bbox 353 1258 1036 1330" in value)

# Extract text from the first div
if div_p23_tag:
    p23_text = div_p23_tag.get_text(strip=True)
else:
    p23_text = ""


# Create TEI XML document
tei_xml = f"""
<TEI>
  <teiHeader>
    <fileDesc>
      <titleStmt>
        <title>{title_text}</title>
        <author>
          <persName></persName>
          <orgName>{org_name_text}</orgName>
        </author>
      </titleStmt>
      <publicationStmt>
        <publPlace>{place_text}</publPlace>
        <date>{date_text}</date>
      </publicationStmt>
    </fileDesc>
  </teiHeader>
  <text>
    <body>
     <head>{h1_text}</head>
    <div type="heading">
        <head>{h2_text}</head>
        <p>{p1_text}</p>
        <p>{p2_text}</p>
        <p>{p3_text}</p>
        <p>{p4_text}</p>
        <p>{p5_text}</p>
        <p>{p6_text}</p>
        </div>
        <div>
        <head>{h3_text}</head>
        <head>{h4_text}</head>
        <list type="number">
        <item n='1'>{l1_text}</item>
        <item n='2'>{l2_text}</item>
        </list>
        <head>{h5_text}</head>
        <head>{h6_text}</head>
        <p>{p7_text}</p>
        <p>{p8_text}</p>
        <p>{p9_text}</p>
        <p>{p10_text}</p>
        <p>{p11_text}</p>
        <p>{p12_text}</p>
        </div>
        <div>
        <head>{h7_text}</head>
        <p>{p13_text}</p>
        <head>{h8_text}</head>
        <p>{p14_text}</p>
        <p>{p15_text}</p>
        <p>{p16_text}</p>
        </div>
        <div>
        <head>{h9_text}</head>
        <p>{p17_text}</p>
        <head>{h10_text}</head>
        <p>{p18_text}</p>
        <p>{p19_text}</p>
        <p>{p20_text}</p>
        <p>{p21_text}</p>
        <p>{p22_text}</p>
        <p>{p23_text}</p>
        </div>
    </body>
  </text>
</TEI>
"""

# Write TEI XML document to file
with open("output_142731.tei.xml", "w", encoding="utf-8") as file:
    file.write(tei_xml)
